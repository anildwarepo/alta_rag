# %%
import json
import search_helper_autodesk as sh


test_data = []

with open('autodesk_index_data_with_vectors.json') as f:
    test_data = json.load(f)
# Out:
# https://aisearch-c2u66zp7iicfc.search.windows.net
# ...
# aml_index_2
# https://anildwaopenaiwestus.openai.azure.com/
# text-embedding-ada-002
# 1536
# 1536
# text-embedding-ada-002
# 2024-06-01
# https://anildwadocintelliwestus2.cognitiveservices.azure.com/

# %%
test_data[0]
# Out:
# {'id': 'baacbdb7-a777-4a00-a863-3f55e5334da7',
#  'doc_name': 'autocad_aca_user_guide_english.pdf.part1.pdf',
#  'page_number': 1,
#  'title': "AutoCAD Architecture 2011 User's Guide",
#  'content': "AutoCAD Architecture 2011 User's Guide Autodesk® March 2010 ",
#  'category': '["Software Documentation", "Architecture Design"]',
#  'tags': '["AutoCAD Architecture", "User Guide", "2011 Edition"]',
#  'lastupdated': '2024-09-03 11:27:59.164015',
#  'titleVector': [-0.007701435126364231,
#   -0.014254996553063393,
#   -0.01708463951945305,
#   0.01875751093029976,
#   0.04061161354184151,
#   0.03203370049595833,
#   -0.010864763520658016,
#   0.052428487688302994,
#   -0.04733869060873985,
#   -0.00953892432153225,
#   -0.003621587762609124,
#   -0.029221853241324425,
#   0.016239305958151817,
#   -0.033421825617551804,
#   0.0022646046709269285,
#   0.053638651967048645,
#   -0.002551573095843196,
#   -0.010588917881250381,
#   0.030236253514885902,
#   -0.052286118268966675,
# ...

# %%
sh.create_index(index_name="autodesk_test")
# Out:
# {'@odata.context': 'https://aisearch-c2u66zp7iicfc.search.windows.net/$metadata#indexes/$entity', '@odata.etag': '"0x8DD302B9712C698"', 'name': 'autodesk_test', 'defaultScoringProfile': None, 'fields': [{'name': 'id', 'type': 'Edm.String', 'searchable': True, 'filterable': True, 'retrievable': True, 'stored': True, 'sortable': True, 'facetable': True, 'key': True, 'indexAnalyzer': None, 'searchAnalyzer': None, 'analyzer': None, 'dimensions': None, 'vectorSearchProfile': None, 'vectorEncoding': None, 'synonymMaps': []}, {'name': 'docName', 'type': 'Edm.String', 'searchable': True, 'filterable': True, 'retrievable': True, 'stored': True, 'sortable': True, 'facetable': True, 'key': False, 'indexAnalyzer': None, 'searchAnalyzer': None, 'analyzer': None, 'dimensions': None, 'vectorSearchProfile': None, 'vectorEncoding': None, 'synonymMaps': []}, {'name': 'pageNumber', 'type': 'Edm.String', 'searchable': True, 'filterable': True, 'retrievable': True, 'stored': True, 'sortable': True, 'face
# ...
